# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df_banana_current = pd.read_csv("testing_standard_buffer_new - urban_burn_buffer_sizes.csv")
df_buffers = pd.read_csv("fire progression -- ALL buffer _ urban_to_TL2 - banana-20-40_buffer_change.csv")
sns.regplot(x="buffer width(m)",y="urban burn(m^2)",data=df_banana_current,fit_reg=True, order=5,ci=None)

# %%
df_banana_current = pd.read_csv("fire progression -- ALL buffer _ urban_to_TL2 - banana-20-40_buffer_change.csv")

# %%
sns.set(color_codes=True)
sns.lmplot(x="time since fire ignited(hour(s))",y="result urban burnt(m^2)", hue="buffer size", data=df_banana_current)

# %%
df_banana_current = pd.read_csv("fire progression -- ALL buffer _ urban_to_TL2 - both20-40_buffer_change.csv")
sns.set(color_codes=True)
sns.lmplot(x="time since fire ignited(hour(s))",y="result urban burnt(m^2)", hue="buffer type", data=df_banana_current)

# %%
sns.relplot(x="time since fire ignited(hour(s))",y="result urban burnt(m^2)",hue = "buffer type",kind="line", data=df_banana_current)

# %%
df_current_veges = pd.read_csv("Banana buffer FARSITE output analysis - banana (4).csv")
df_current_veges
# Out:
#     index weather condition buffer size(m)  min time arrival  \
# 0       1              2017              0          971.3846
# 1       2              2017            633         1054.2025
# 2       3             rcp45              0               NaN
# 3       4             rcp45            633               NaN
# 4       5             rcp85             no               NaN
# 5       6             rcp85            633               NaN
# 6       7              2017           1280               NaN
# 7       8             rcp45           1280               NaN
# 8       9             rcp85           1280               NaN
# 9      10              2017            399               NaN
# 10     11             rcp45            399               NaN
# 11     12             rcp85            399               NaN
# 12     13              2017            200               NaN
# 13     14             rcp45            200               NaN
# 14     15             rcp85            200               NaN
#
#     avg time arrval 1(min)  avg time arrval 2  avg time arrval 3  \
# 0                1429.0867          1488.9491          1449.8912
# 1                1616.2136          1605.9058          1613.5731
# 2                1471.3939          1430.5118          1428.0636
# 3                1629.0290          1597.2400          1611.2701
# 4                1470.2620          1449.0897          1528.9459
# 5                1624.3910          1595.4954          1602.8065
# 6                1697.0200          1685.9851          1679.8412
# 7                1655.4340          1679.0171          1669.7977
# 8                1658.7435          1634.0038          1644.3881
# 9                1643.2938          1683.9010          1679.8412
# 10               1582.1738          1606.1580          1676.0681
# 11               1591.9528          1563.3549          1622.0785
# 12               1436.2423          1548.5543          1567.2540
# 13               1494.9337          1569.6805          1527.3369
# 14               1539.4431          1504.7965                NaN
#
#     ave ave time arrival (min)  ave fireline intensity 1  \
# 0                  1455.975667                567.099200
# 1                  1611.897500                 28.865185
# 2                  1443.323100                551.103800
# 3                  1612.513033                 12.582721
# 4                  1482.765867                686.516100
# 5                  1607.564300                 12.598832
# 6                  1687.615433                  7.482253
# 7                  1668.082933                 10.896090
# 8                  1645.711800                  8.351534
# 9                  1669.012000                       NaN
# 10                 1621.466633                173.538200
# 11                 1592.462067                208.073580
# 12                 1517.350200                308.224800
# 13                 1530.650367                349.409120
# 14                 1522.119800                347.679200
#
#     ave fireline intensity 2  ave fireline intensity 3  \
# 0                 514.578600                520.862850
# 1                  22.384840                  7.102820
# 2                 580.592400                618.047300
# 3                  17.673107                  9.808544
# 4                 633.322940                610.239800
# 5                  18.490353                  8.040596
# 6                   8.782038                  9.050657
# 7                   4.247856                 17.656979
# 8                   7.665098                  5.843556
# 9                 163.083100                145.421200
# 10                190.292040                166.844700
# 11                204.954960                180.786350
# 12                276.687130                283.469300
# 13                323.034500                336.447720
# 14                379.231900                       NaN
#
#     avg avg fireline intenstiy
# 0                   534.180217
# 1                    19.450948
# 2                   583.247833
# 3                    13.354791
# 4                   643.359613
# 5                    13.043260
# 6                     8.438316
# 7                    10.933642
# 8                     7.286729
# 9                   154.252150
# 10                  176.891647
# 11                  197.938297
# 12                  289.460410
# 13                  336.297113
# 14                  363.455550

# %%
df_current_veges = pd.read_csv("Banana buffer FARSITE output analysis - banana-2.csv")
sns.set(color_codes=True)
sns.lmplot(x="buffer size(m)",y="fireline intensity(kW/m)", hue="weather condition", data=df_current_veges)

# %%
df_vineyard_box
# Out:
#     index weather condition  buffer size(m)  avg time arrval(min)  \
# 0       1              2017               0             1429.0867
# 1       2              2017             633             1616.2136
# 2       3             rcp45               0             1471.3939
# 3       4             rcp45             633             1629.0290
# 4       5             rcp85               0             1470.2620
# 5       6             rcp85             633             1624.3910
# 6       7              2017            1280             1697.0200
# 7       8             rcp45            1280             1655.4340
# 8       9             rcp85            1280             1658.7435
# 9      10              2017             399             1643.2938
# 10     11             rcp45             399             1582.1738
# 11     12             rcp85             399             1591.9528
# 12     13              2017             200             1436.2423
# 13     14             rcp45             200             1494.9337
# 14     15             rcp85             200             1539.4431
# 15     16              2017               0             1488.9491
# 16     17              2017             633             1605.9058
# 17     18             rcp45               0             1430.5118
# 18     19             rcp45             633             1597.2400
# 19     20             rcp85               0             1449.0897
# 20     21             rcp85             633             1595.4954
# 21     22              2017            1280             1685.9851
# 22     23             rcp45            1280             1679.0171
# 23     24             rcp85            1280             1634.0038
# 24     25              2017             399             1683.9010
# 25     26             rcp45             399             1606.1580
# 26     27             rcp85             399             1563.3549
# 27     28              2017             200             1548.5543
# 28     29             rcp45             200             1569.6805
# 29     30             rcp85             200             1504.7965
# 30     31              2017               0             1449.8912
# 31     32              2017             633             1613.5731
# 32     33             rcp45               0             1428.0636
# 33     34             rcp45             633             1611.2701
# 34     35             rcp85               0             1528.9459
# 35     36             rcp85             633             1602.8065
# 36     37              2017            1280             1679.8412
# 37     38             rcp45            1280             1669.7977
# 38     39             rcp85            1280             1644.3881
# 39     40              2017             399             1679.8412
# 40     41             rcp45             399             1676.0681
# 41     42             rcp85             399             1622.0785
# 42     43              2017             200             1567.2540
# 43     44             rcp45             200             1527.3369
# 44     45             rcp85             200             1507.0422
#
#     fireline intensity(kW/m)
# 0                 567.099200
# 1                  28.865185
# 2                 551.103800
# 3                  12.582721
# 4                 686.516100
# 5                  12.598832
# 6                   7.482253
# 7                  10.896090
# 8                   8.351534
# 9                        NaN
# 10                173.538200
# 11                208.073580
# 12                308.224800
# 13                349.409120
# 14                347.679200
# 15                514.578600
# 16                 22.384840
# 17                580.592400
# 18                 17.673107
# 19                633.322940
# 20                 18.490353
# 21                  8.782038
# 22                  4.247856
# 23                  7.665098
# 24                163.083100
# 25                190.292040
# 26                204.954960
# 27                276.687130
# 28                323.034500
# 29                379.231900
# 30                520.862850
# 31                  7.102820
# 32                618.047300
# 33                  9.808544
# 34                610.239800
# 35                  8.040596
# 36                  9.050657
# 37                 17.656979
# 38                  5.843556
# 39                145.421200
# 40                166.844700
# 41                180.786350
# 42                283.469300
# 43                336.447720
# 44                387.325300

# %% [markdown]
# - hector

# %%
df_vineyard_box = pd.read_csv("Banana buffer FARSITE output analysis - Sheet3 (2).csv")
sns.set(style="white")
plt.figure(figsize=(14,10))
#plt.style.use('classic')
#fig, ax = plt.subplots()
#plt.title('Vineyard/Orchard Fire Buffers Comparison')
sns_plot = sns.boxplot(x="buffer size(m)",y="avg time arrval(min)", 
                  hue="weather condition", data=df_vineyard_box, linewidth=3.5, palette=['#66c2a5','#fc8d62','#8da0cb'],  width = 0.3)

#plt.suptitle("3(c). Vineyard Fire Buffers Comparison")
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_vineyard_box, color=".25", ax=ax)
#sns.lmplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", hue="buffer type", data=df_vineyard_box)
#sns_plot.axes.set_title("Vineyard/Orchard Fire Buffers Comparison",fontsize=30)
sns_plot.set_xlabel("Banana buffer width",fontsize=25)

sns_plot.set_ylabel("Average fire arrival time (min)",fontsize=30)

sns_plot.tick_params(labelsize=25)
sns_plot.set_xticklabels(['No buffer', 'Very small', 'Small', 'Medium', 'Very large'])
handles, _ = sns_plot.get_legend_handles_labels() 
plt.legend(handles, ["2017","RCP45", "RCP85"],fontsize=30, title_fontsize=3)
filename = 'figures_submission/' + 'farsite_arrival_time'
sns_plot.figure.savefig(filename + ".pdf")
sns_plot.figure.savefig(filename + ".png")


plt.show()

# %%
df_vineyard_box = pd.read_csv("Banana buffer FARSITE output analysis - banana (7).csv")
sns.set(style="white")
plt.figure(figsize=(14,10))
#plt.style.use('classic')
#fig, ax = plt.subplots()
#plt.title('Vineyard/Orchard Fire Buffers Comparison')
sns_plot = sns.boxplot(x="buffer size(m)",y="fireline intensity(kW/m)",
                  hue="weather condition",data=df_vineyard_box,linewidth=3.5, palette=['#66c2a5','#fc8d62','#8da0cb'], width = 0.3)

#plt.suptitle("3(c). Vineyard Fire Buffers Comparison")
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_vineyard_box, color=".25", ax=ax)
#sns.lmplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", hue="buffer type", data=df_vineyard_box)
#sns_plot.axes.set_title("Vineyard/Orchard Fire Buffers Comparison",fontsize=30)
sns_plot.set_xlabel("Banana buffer width",fontsize=25)

sns_plot.set_ylabel("Fireline intensity (kW/m)",fontsize=25)
sns_plot.axhline(1239.7328, c = 'r')
sns_plot.text(0.55, 1240, "Medium vineyard", ha='right', fontsize = 20)
sns_plot.axhline(826, ls=':', c = 'g')
sns_plot.text(0, 826, "Control",ha='right', fontsize = 20)
sns_plot.axhline(948.5, ls='-.', c = 'g')
sns_plot.text(0.5, 948.5, "Mechanical only", ha='right', fontsize = 20)
sns_plot.axhline(29.1, ls='--', c = 'g')
sns_plot.text(0.55, 29.1, "Mechanical + fire", ha='right',fontsize = 20)
sns_plot.axhline(21, ls=':', c = 'g')
sns_plot.text(0.07, 21, "Fire only", ha='right', va = 'top', fontsize = 20)
sns_plot.tick_params(labelsize=20)
sns_plot.set_xticklabels(['No buffer', 'Very small', 'Small', 'Medium', 'Very large'])
handles, _ = sns_plot.get_legend_handles_labels() 
plt.legend(handles, ["2017","RCP45", "RCP85"],fontsize=25, title_fontsize=25)
filename = 'figures_submission/' + 'fireline_intensity'
sns_plot.figure.savefig(filename + ".pdf")
sns_plot.figure.savefig(filename + ".png")
plt.show()

# %%
df_current_yearx_box = pd.read_csv("evaluation/Banana buffer FARSITE output analysis - banana (5).csv")
fig, ax = plt.subplots()
sns.boxenplot(x="buffer size(m)", y="avg avg fireline intenstiy", 
                  hue="weather condition", data=df_current_yearx_box, linewidth=1, palette="Set3", ax=ax)
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_current_yearx_box, color=".25", ax=ax)
#sns.lmplot(x="time since fire ignited(hour(s))",y="result urban burnt(m^2)", hue="climate type", data=df_current_yearx_box)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-00937ac85928> in <module>
# ----> 1 df_current_yearx_box = pd.read_csv("evaluation/Banana buffer FARSITE output analysis - banana (5).csv")
#       2 fig, ax = plt.subplots()
#       3 sns.boxenplot(x="buffer size(m)", y="avg avg fireline intenstiy",
#       4                   hue="weather condition", data=df_current_yearx_box, linewidth=1, palette="Set3", ax=ax)
#       5 #sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_current_yearx_box, color=".25", ax=ax)
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File evaluation/Banana buffer FARSITE output analysis - banana (5).csv does not exist: 'evaluation/Banana buffer FARSITE output analysis - banana (5).csv'

# %%
color_banana = ['#a6cee3','#1f78b4', '#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a','#ffff99','#b15928']

no_buffer_2017 = '#a6cee3'
small_banana = '#1f78b4'
medium_banana = '#b2df8a'
large_banana = '#33a02c'
very_large_banana = '#fb9a99'
NB3_small = '#e31a1c'
NB3_medium = '#fdbf6f'
NB3_very_large = '#ff7f00'
vineyard_medium = '#cab2d6'
color_rcp = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9']
no_buffer_rcp45 = '#8dd3c7'
small_banana_rcp45 = '#ffffb3'
medium_banana_rcp45 = '#bebada'
very_large_banana_rcp45 = '#fb8072'
no_buffer_rcp85 = '#80b1d3'
small_buffer
sns.set_palette(color_banana)
sns.palplot(sns.color_palette())

# %%
df_fi = pd.read_csv("evaluation/Banana buffer FARSITE output analysis - banana (1).csv")
sns.set(style="whitegrid")
plt.figure(figsize=(14,10))
#plt.style.use('classic')
#fig, ax = plt.subplots()
#plt.title('Vineyard/Orchard Fire Buffers Comparison')
sns_plot = sns.boxplot(x="buffer size(m)",y="Urban area burned (square meters)", 
                  hue="Buffer type", data=df_vineyard_box, linewidth=3.5, palette=color_banana, order=range(17, 39, 3))

#plt.suptitle("3(c). Vineyard Fire Buffers Comparison")
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_vineyard_box, color=".25", ax=ax)
#sns.lmplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", hue="buffer type", data=df_vineyard_box)
#sns_plot.axes.set_title("Vineyard/Orchard Fire Buffers Comparison",fontsize=30)
sns_plot.set_xlabel("Time since fire ignition (hours)",fontsize=25)
sns_plot.set_ylabel("Urban area burned $(m^2)$",fontsize=25)
sns_plot.tick_params(labelsize=20)
plt.legend(fontsize=25, title_fontsize=25)

plt.show()

# %%
df_vineyard_box = pd.read_csv("fire progression -- 633 buffer _ urban_to_TL2 - vegetation_types_633_box (5).csv")
sns.set(style="whitegrid")
plt.figure(figsize=(14,10))
#plt.style.use('classic')
#fig, ax = plt.subplots()
#plt.title('Vineyard/Orchard Fire Buffers Comparison')
sns_plot = sns.boxplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", 
                  hue="Buffer type", data=df_vineyard_box, linewidth=4, palette=['#ff7f00','#a6cee3','#b2df8a'], order=range(17, 39, 3))
sns_plot.set(ylim=(0,28000000))
#plt.suptitle("3(c). Vineyard Fire Buffers Comparison")
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_vineyard_box, color=".25", ax=ax)
#sns.lmplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", hue="buffer type", data=df_vineyard_box)
#sns_plot.axes.set_title("Vineyard/Orchard Fire Buffers Comparison",fontsize=30)
sns_plot.set_xticklabels(sns_plot.get_xticklabels(), fontsize=25)
sns_plot.set_xlabel("Time since fire ignition (hours)",fontsize=25)
#sns_plot.set_ylabel("Urban area burned $(m^2)$",fontsize=25)
sns_plot.tick_params(labelsize=20)
sns_plot.set_yticklabels([0, 5, 10, 15, 20, 25])
sns_plot.set_ylabel("Urban area burned (km$^2$)",fontsize=25)
handles, _ = sns_plot.get_legend_handles_labels() 
plt.legend(handles, ["Vineyard medium","No buffer", "Banana medium"],fontsize=25, title_fontsize=25)

plt.show()
filename = 'figures_submission/' + 'vineyard_urban_burned_comparison'
sns_plot.figure.savefig(filename + ".pdf")
sns_plot.figure.savefig(filename + ".png")

# %%
df_vineyard_box = pd.read_csv("fire progression -- ALL buffer _ urban_to_TL2 - 20-40_boz (1).csv")
sns.set(style="whitegrid")
#plt.style.use('classic')
plt.figure(figsize=(14,10))

#plt.title('Baseline Tubbs Fire Buffers')
sns_plot = sns.boxplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", 
                  hue="Buffer type", data=df_vineyard_box, linewidth=4, palette=color_banana, order=range(21, 40, 3))
#sns_plot.axes.set_title("Baseline Tubbs Fire Buffers",fontsize=30)
sns_plot.set(ylim=(0,28000000))
sns_plot.set_xlabel("Time since fire ignition (hours)",fontsize=25)
sns_plot.set_ylabel("Urban area burned $(m^2)$",fontsize=25)
sns_plot.tick_params(labelsize=20)
plt.legend(fontsize=25, title_fontsize=25)
sns_plot.set_yticklabels([0, 5, 10, 15, 20, 25])
sns_plot.set_ylabel("Urban area burned (km$^2$)",fontsize=25)
#plt.suptitle("3(c). Vineyard Fire Buffers Comparison")
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_vineyard_box, color=".25", ax=ax)
#sns.lmplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", hue="buffer type", data=df_vineyard_box)
handles, _ = sns_plot.get_legend_handles_labels() 
plt.legend(handles, ["No buffer","NB3 small", "Banana medium", "NB3 medium", "Banana medium", 
                     "Banana very large", "NB3 very large"],fontsize=25, title_fontsize=25)
#for line in sns_plot.get_lines():
#    line.set_color('orange')
plt.show()
filename = 'figures_submission/' + 'NB3_Banana_2017tubbs_urban_burned'
sns_plot.figure.savefig(filename + ".pdf")
sns_plot.figure.savefig(filename + ".png")

# %%
df_vineyard_box = pd.read_csv("fire progression -- 2090 _ urban_to_TL2 - rcp45_buffer_formal_box.csv")
sns.set(style="whitegrid")
#plt.style.use('classic')
plt.figure(figsize=(14,10))
#plt.title('YOUR TITLE HERE')
sns_plot = sns.boxplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", 
                  hue="Buffer type", data=df_vineyard_box, linewidth=4, palette=['#8dd3c7','#ffffb3','#bebada','#fb8072'], order=range(17, 40, 3))
#sns_plot.axes.set_title("RCP 4.5 Tubbs Fire Buffers 2090",fontsize=30)
sns_plot.set_xlabel("Time since fire ignition (hours)",fontsize=25)
#sns_plot.set_ylabel("Urban area burned $(m^2)$",fontsize=25)
sns_plot.tick_params(labelsize=20)
sns_plot.set(ylim=(0,28000000))
plt.legend(fontsize=25, title_fontsize=25)
sns_plot.set_yticklabels([0, 5, 10, 15, 20, 25])
sns_plot.set_ylabel("Urban area burned (km$^2$)",fontsize=25)
#plt.suptitle("3(c). Vineyard Fire Buffers Comparison")
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_vineyard_box, color=".25", ax=ax)
#sns.lmplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", hue="buffer type", data=df_vineyard_box)
handles, _ = sns_plot.get_legend_handles_labels() 
plt.legend(handles, ["RCP45 no buffer","RCP45 banana small", "RCP45 banana medium","RCP45 banana very large"],fontsize=25, title_fontsize=25)

plt.show()
filename = 'figures_submission/' + 'rcp45_banana_sizes_urban_burned'
sns_plot.figure.savefig(filename + ".pdf")
sns_plot.figure.savefig(filename + ".png")

# %%
df_vineyard_box = pd.read_csv("fire progression -- 2090 _ urban_to_TL2 - rcp85_box 2.csv")
sns.set(style="whitegrid")
#plt.style.use('classic')
plt.figure(figsize=(14,10))
#plt.title('YOUR TITLE HERE')
sns_plot = sns.boxplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", 
                  hue="Buffer type", data=df_vineyard_box, linewidth=4, palette=['#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9'], order=range(17, 40, 3))
sns_plot.set(ylim=(0,28000000))
#plt.suptitle("3(c). Vineyard Fire Buffers Comparison")
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_vineyard_box, color=".25", ax=ax)
#sns.lmplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", hue="buffer type", data=df_vineyard_box)
#sns_plot.axes.set_title("RCP 8.5 Tubbs Fire Buffers 2090",fontsize=30)
sns_plot.set_xlabel("Time since fire ignition (hours)",fontsize=25)
#sns_plot.set_ylabel("Urban area burned $(m^2)$",fontsize=25)
sns_plot.tick_params(labelsize=20)
sns_plot.set_yticklabels([0, 5, 10, 15, 20, 25])
sns_plot.set_ylabel("Urban area burned (km$^2$)",fontsize=25)
plt.legend(fontsize=25, title_fontsize=25)
handles, _ = sns_plot.get_legend_handles_labels() 
plt.legend(handles, ["RCP85 no buffer", "RCP85 banana small", "RCP85 banana medium", "RCP85 banana very large"],fontsize=25, title_fontsize=25)

plt.show()
filename = 'figures_submission/' + 'rcp85_banana_sizes_urban_burn'
sns_plot.figure.savefig(filename + ".pdf")
sns_plot.figure.savefig(filename + ".png")

# %%
df_vineyard_box = pd.read_csv("fire_buffer_testing - Sheet1.csv")
sns.set(style="whitegrid")
#plt.style.use('classic')
plt.figure(figsize=(14,10))
#plt.title('YOUR TITLE HERE')
sns_plot = sns.boxplot(x="Buffer width(m)",y="Urban area burned (square meters)", 
                  data=df_vineyard_box, linewidth=4, palette=['#a6cee3', '#b2df8a','#fb9a99','#cab2d6','#fdbf6f'], width = 0.3)
sns_plot.set(ylim=(0,28000000))
#plt.suptitle("3(c). Vineyard Fire Buffers Comparison")
#sns.swarmplot(x="time since fire ignited(hour(s))", y="result urban burnt(m^2)", data=df_vineyard_box, color=".25", ax=ax)
#sns.lmplot(x="Time since fire ignition (hours)",y="Urban area burned (square meters)", hue="buffer type", data=df_vineyard_box)
#sns_plot.axes.set_title("Buffer Sizing Diagram",fontsize=30)
sns_plot.set_xlabel("Buffer width",fontsize=25)

sns_plot.tick_params(labelsize=20)
sns_plot.set_xticklabels(['No buffer', 'Very small', 'Small', 'Medium', 'Very large'])
sns_plot.set_yticklabels([0, 5, 10, 15, 20, 25])
sns_plot.set_ylabel("Urban area burned (km$^2$)",fontsize=25)
#plt.legend(fontsize=25, title_fontsize=25)

plt.show()
filename = 'figures_submission/' + 'buffer_widths_impacting_2017_tubbs_urban_burn'
sns_plot.figure.savefig(filename + ".pdf")
sns_plot.figure.savefig(filename + ".png")

# %%
df_banana_climate = pd.read_csv("fire progression -- 2090 _ urban_to_TL2 - 2090rcpall (2).csv")
sns.set(color_codes=True)
sns.lmplot(x="time since fire ignited(hour(s))",y="result urban burnt(m^2)", hue="climate type", data=df_banana_climate)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-268ea452eecb> in <module>
#       1 df_banana_climate = pd.read_csv("fire progression -- 2090 _ urban_to_TL2 - rcp45_buffer_formal_box.csv")
#       2 sns.set(color_codes=True)
# ----> 3 sns.lmplot(x="time since fire ignited(hour(s))",y="result urban burnt(m^2)", hue="climate type", data=df_banana_climate)
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     576     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     577     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 578     data = data[cols]
#     579
#     580     # Initialize the grid
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# /opt/anaconda3/envs/gdal_vegetation_wildfire/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['climate type', 'result urban burnt(m^2)',\n       'time since fire ignited(hour(s))'],\n      dtype='object')] are in the [columns]"

# %%
df_banana_rcp45 = pd.read_csv("fire progression -- 2090 _ urban_to_TL2 - rcp45_buffer_formal (2).csv")
sns.set(color_codes=True)
sns.lmplot(x="time since fire ignited(hour(s))",y="result urban burnt(m^2)", hue="buffer type", data=df_banana_rcp45)

# %%
df_banana_rcp85 = pd.read_csv("fire progression -- 2090 _ urban_to_TL2 - rcp85 (5).csv")
sns.set(color_codes=True)
sns.lmplot(x="time since fire ignited(hour(s))",y="result urban burnt(m^2)", hue="buffer type", data=df_banana_rcp85)
